# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
gdp_df=pd.read_csv('../data/gdp_percapita.csv',nrows=6868)
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %%
internet_df=pd.read_csv('../data/internet_use.csv', nrows=4495)
internet_df.tail()
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %%
gdp_df.head(6)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2019  2065.036398              NaN
# 1     Afghanistan  2018  2033.779002              NaN
# 2     Afghanistan  2017  2058.383832              NaN
# 3     Afghanistan  2016  2057.062164              NaN
# 4     Afghanistan  2015  2068.265904              NaN
# 5     Afghanistan  2014  2102.385234              NaN

# %%
internet_df.head(6)
# Out:
#   Country or Area  Year     Value  Value Footnotes
# 0     Afghanistan  2014  6.390000              NaN
# 1     Afghanistan  2013  5.900000              NaN
# 2     Afghanistan  2012  5.454545              NaN
# 3     Afghanistan  2011  5.000000              NaN
# 4     Afghanistan  2010  4.000000              NaN
# 5     Afghanistan  2009  3.550000              NaN

# %%
gdp_df.shape
# Out:
# (6868, 4)

# %%
internet_df.shape
# Out:
# (4495, 4)

# %%
gdp_df['Country or Area'].dtype
# Out:
# dtype('O')

# %%
internet_df['Country or Area'].dtype
# Out:
# dtype('O')

# %%
gdp_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %%
internet_df.dtypes
# Out:
# Country or Area     object
# Year                 int64
# Value              float64
# Value Footnotes    float64
# dtype: object

# %% [markdown]
# making note of this shortcut for checking data types. Make sure you add an s onto the end of type!

# %%
gdp_df.tail(10)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 6858        Zimbabwe  1999  3600.849291              NaN
# 6859        Zimbabwe  1998  3653.920016              NaN
# 6860        Zimbabwe  1997  3580.048793              NaN
# 6861        Zimbabwe  1996  3520.430146              NaN
# 6862        Zimbabwe  1995  3226.413930              NaN
# 6863        Zimbabwe  1994  3263.934978              NaN
# 6864        Zimbabwe  1993  3033.504852              NaN
# 6865        Zimbabwe  1992  3054.889178              NaN
# 6866        Zimbabwe  1991  3426.598094              NaN
# 6867        Zimbabwe  1990  3324.348171              NaN

# %%
internet_df.tail(10)
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 4485        Zimbabwe  2002  3.994356              NaN
# 4486        Zimbabwe  2001  0.799846              NaN
# 4487        Zimbabwe  2000  0.401434              NaN
# 4488        Zimbabwe  1999  0.161676              NaN
# 4489        Zimbabwe  1998  0.081648              NaN
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN

# %%
gdp_df.drop(columns='Value Footnotes')
# Out:
#      Country or Area  Year        Value
# 0        Afghanistan  2019  2065.036398
# 1        Afghanistan  2018  2033.779002
# 2        Afghanistan  2017  2058.383832
# 3        Afghanistan  2016  2057.062164
# 4        Afghanistan  2015  2068.265904
# ...              ...   ...          ...
# 6863        Zimbabwe  1994  3263.934978
# 6864        Zimbabwe  1993  3033.504852
# 6865        Zimbabwe  1992  3054.889178
# 6866        Zimbabwe  1991  3426.598094
# 6867        Zimbabwe  1990  3324.348171
#
# [6868 rows x 3 columns]

# %%
internet_df.drop(columns='Value Footnotes')
# Out:
#      Country or Area  Year     Value
# 0        Afghanistan  2014  6.390000
# 1        Afghanistan  2013  5.900000
# 2        Afghanistan  2012  5.454545
# 3        Afghanistan  2011  5.000000
# 4        Afghanistan  2010  4.000000
# ...              ...   ...       ...
# 4490        Zimbabwe  1997  0.033080
# 4491        Zimbabwe  1996  0.016790
# 4492        Zimbabwe  1995  0.007684
# 4493        Zimbabwe  1994  0.001739
# 4494        Zimbabwe  1990  0.000000
#
# [4495 rows x 3 columns]

# %%
gdp_df=gdp_df.rename(columns={'Country or Area':'Country','Value':'GDP_Per_Capita'}).drop(columns='Value Footnotes')

# %%
internet_df=internet_df.rename(columns={'Country or Area':'Country','Value':'Internet_Users_Pct'}).drop(columns='Value Footnotes')

# %%
gdp_df
# Out:
#           Country  Year  GDP_Per_Capita
# 0     Afghanistan  2019     2065.036398
# 1     Afghanistan  2018     2033.779002
# 2     Afghanistan  2017     2058.383832
# 3     Afghanistan  2016     2057.062164
# 4     Afghanistan  2015     2068.265904
# ...           ...   ...             ...
# 6863     Zimbabwe  1994     3263.934978
# 6864     Zimbabwe  1993     3033.504852
# 6865     Zimbabwe  1992     3054.889178
# 6866     Zimbabwe  1991     3426.598094
# 6867     Zimbabwe  1990     3324.348171
#
# [6868 rows x 3 columns]

# %%
internet_df
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %%
gdp_and_internet_use=pd.merge(gdp_df,internet_df, on=['Country','Year'], how='outer')

# %%
gdp_and_internet_use
# Out:
#           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0     Afghanistan  2019     2065.036398                 NaN
# 1     Afghanistan  2018     2033.779002                 NaN
# 2     Afghanistan  2017     2058.383832                 NaN
# 3     Afghanistan  2016     2057.062164                 NaN
# 4     Afghanistan  2015     2068.265904                 NaN
# ...           ...   ...             ...                 ...
# 7900        Yemen  1999             NaN            0.056629
# 7901        Yemen  1998             NaN            0.023323
# 7902        Yemen  1997             NaN            0.015025
# 7903        Yemen  1996             NaN            0.000621
# 7904        Yemen  1990             NaN            0.000000
#
# [7905 rows x 4 columns]

# %%
gdp_and_internet_use.head(10)
# Out:
#        Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 0  Afghanistan  2019     2065.036398                 NaN
# 1  Afghanistan  2018     2033.779002                 NaN
# 2  Afghanistan  2017     2058.383832                 NaN
# 3  Afghanistan  2016     2057.062164                 NaN
# 4  Afghanistan  2015     2068.265904                 NaN
# 5  Afghanistan  2014     2102.385234            6.390000
# 6  Afghanistan  2013     2116.465454            5.900000
# 7  Afghanistan  2012     2075.491747            5.454545
# 8  Afghanistan  2011     1904.559799            5.000000
# 9  Afghanistan  2010     1957.029338            4.000000

# %%
gdp_and_internet_use.tail(10)
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7895   Yemen  2004             NaN            0.881223
# 7896   Yemen  2003             NaN            0.604734
# 7897   Yemen  2002             NaN            0.518796
# 7898   Yemen  2001             NaN            0.090802
# 7899   Yemen  2000             NaN            0.082500
# 7900   Yemen  1999             NaN            0.056629
# 7901   Yemen  1998             NaN            0.023323
# 7902   Yemen  1997             NaN            0.015025
# 7903   Yemen  1996             NaN            0.000621
# 7904   Yemen  1990             NaN            0.000000

# %% [markdown]
# 13.	Subset the combined DataFrame to keep only the data for 2004, 2009, and 2014. Check that this happened correctly.

# %%
my_list = [2004, 2009, 2014]
new = gdp_and_internet_use.query("Year in @my_list")
new
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5               Afghanistan  2014     2102.385234            6.390000
# 10              Afghanistan  2009     1758.904043            3.550000
# 15              Afghanistan  2004     1200.278256            0.105809
# 23                  Albania  2014    11623.866679           60.100000
# 28                  Albania  2009    10346.864199           41.200000
# ...                     ...   ...             ...                 ...
# 7868  Virgin Islands (U.S.)  2009             NaN           27.396510
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7885                  Yemen  2014             NaN           22.550000
# 7890                  Yemen  2009             NaN            9.960000
# 7895                  Yemen  2004             NaN            0.881223
#
# [830 rows x 4 columns]

# %%
gdp_and_internet_use.dtypes
# Out:
# Country                object
# Year                    int64
# GDP_Per_Capita        float64
# Internet_Users_Pct    float64
# dtype: object

# %%
type(gdp_and_internet_use.Country)
# Out:
# pandas.core.series.Series

# %%
year04_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == 2004)]
year04_df
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 15              Afghanistan  2004     1200.278256            0.105809
# 33                  Albania  2004     7604.838002            2.420388
# 63                  Algeria  2004    10058.435939            4.634475
# 93                   Angola  2004     5593.241537            0.464815
# 123     Antigua and Barbuda  2004    18745.681534           24.266544
# ...                     ...   ...             ...                 ...
# 7771     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7829              Venezuela  2004             NaN            8.404470
# 7853               Viet Nam  2004             NaN            7.642409
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7895                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
year09_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == 2009)]
year09_df
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 10              Afghanistan  2009     1758.904043             3.55000
# 28                  Albania  2009    10346.864199            41.20000
# 58                  Algeria  2009    10782.361398            11.23000
# 88                   Angola  2009     7643.493749             6.00000
# 118     Antigua and Barbuda  2009    20046.839017            42.00000
# ...                     ...   ...             ...                 ...
# 7766     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 7824              Venezuela  2009             NaN            32.70000
# 7848               Viet Nam  2009             NaN            26.55000
# 7868  Virgin Islands (U.S.)  2009             NaN            27.39651
# 7890                  Yemen  2009             NaN             9.96000
#
# [277 rows x 4 columns]

# %%
year14_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == 2014)]
year14_df
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 5               Afghanistan  2014     2102.385234                6.39
# 23                  Albania  2014    11623.866679               60.10
# 53                  Algeria  2014    11512.705405               18.09
# 83                   Angola  2014     8239.828837               21.26
# 113     Antigua and Barbuda  2014    18104.241470               64.00
# ...                     ...   ...             ...                 ...
# 7761     T.F.Y.R. Macedonia  2014             NaN               68.06
# 7819              Venezuela  2014             NaN               57.00
# 7843               Viet Nam  2014             NaN               48.31
# 7863  Virgin Islands (U.S.)  2014             NaN               50.07
# 7885                  Yemen  2014             NaN               22.55
#
# [277 rows x 4 columns]

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending= False).head(1)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2625  Iceland  2014      49652.1495               98.16

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending= True).head(1)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7079  Dem. People's Rep. of Korea  2014             NaN                 0.0

# %%
year04_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == 2004)]
year04_df
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 15              Afghanistan  2004     1200.278256            0.105809
# 33                  Albania  2004     7604.838002            2.420388
# 63                  Algeria  2004    10058.435939            4.634475
# 93                   Angola  2004     5593.241537            0.464815
# 123     Antigua and Barbuda  2004    18745.681534           24.266544
# ...                     ...   ...             ...                 ...
# 7771     T.F.Y.R. Macedonia  2004             NaN           24.440000
# 7829              Venezuela  2004             NaN            8.404470
# 7853               Viet Nam  2004             NaN            7.642409
# 7873  Virgin Islands (U.S.)  2004             NaN           27.377009
# 7895                  Yemen  2004             NaN            0.881223
#
# [276 rows x 4 columns]

# %%
year04_df.sort_values(by = 'Internet_Users_Pct', ascending= False).head(1)
# Out:
#      Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6019  Sweden  2004    44496.023401               83.89

# %%
year04_df.sort_values(by = 'Internet_Users_Pct', ascending= True).head(1)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7088  Dem. People's Rep. of Korea  2004             NaN                 0.0

# %%
year09_df = gdp_and_internet_use[(gdp_and_internet_use['Year'] == 2009)]
year09_df
# Out:
#                     Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 10              Afghanistan  2009     1758.904043             3.55000
# 28                  Albania  2009    10346.864199            41.20000
# 58                  Algeria  2009    10782.361398            11.23000
# 88                   Angola  2009     7643.493749             6.00000
# 118     Antigua and Barbuda  2009    20046.839017            42.00000
# ...                     ...   ...             ...                 ...
# 7766     T.F.Y.R. Macedonia  2009             NaN            51.77000
# 7824              Venezuela  2009             NaN            32.70000
# 7848               Viet Nam  2009             NaN            26.55000
# 7868  Virgin Islands (U.S.)  2009             NaN            27.39651
# 7890                  Yemen  2009             NaN             9.96000
#
# [277 rows x 4 columns]

# %%
year09_df.sort_values(by = 'Internet_Users_Pct', ascending= False).head(1)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2630  Iceland  2009    48177.084123                93.0

# %%
year09_df.sort_values(by = 'Internet_Users_Pct', ascending= True).head(1)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7083  Dem. People's Rep. of Korea  2009             NaN                 0.0

# %%
year14_df.sort_values(by = 'GDP_Per_Capita', ascending= False).head(1)
# Out:
#                Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 3721  Macao SAR, China  2014    156514.13385                 NaN

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending= True).head(1)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7079  Dem. People's Rep. of Korea  2014             NaN                 0.0

# %% [markdown]
# 21.	Create some scatterplots:
#     a.  2004 Percent Using the Internet vs GDP Per Capita
#     b.	2009 Percent Using the Internet vs GDP Per Capita
#     c.	2014 Percent Using the Internet vs GDP Per Capita

# %%
plt.scatter(x='GDP_Per_Capita',y='Internet_Users_Pct',data=year04_df);

# %%
plt.scatter(x='GDP_Per_Capita',y='Internet_Users_Pct',data=year09_df);

# %%
plt.scatter(x='GDP_Per_Capita',y='Internet_Users_Pct',data=year14_df);

# %% [markdown]
# 22.	Are there differences across years? What do the plots tell you about any relationship between these two variables? Enter your observations as a markdown cell.

# %% [markdown]
# Internet becuase cheper as more users were able to afford in countries with lower GDPs.

# %% [markdown]
# 23.	Look at the distribution of gdp per capita values for 2014. Is it unimodal?

# %%
plt.hist(x='GDP_Per_Capita',data=year14_df);

# %% [markdown]
# YES

# %% [markdown]
# 24.	Look at the distribution of Internet Use for 2014. Is it unimodal?

# %%
plt.hist(x='Internet_Users_Pct',data=year14_df);

# %% [markdown]
# NO

# %% [markdown]
# What are the top 5 countries in terms of internet use in 2014?

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending= False).head(5)
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 2625  Iceland  2014    49652.149500               98.16
# 561   Bermuda  2014    77361.104881               96.80
# 4648   Norway  2014    62589.373548               96.30
# 1452  Denmark  2014    52214.537753               95.99
# 6871  Andorra  2014             NaN               95.90

# %%
my_list = ['Iceland','Bermuda','Norway','Denmark','Andorra']
top_5_2004=year04_df.query('Country in @my_list')
top_5_2004
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 571   Bermuda  2004    90195.811033           60.990867
# 1462  Denmark  2004    50607.628971           80.930000
# 2635  Iceland  2004    45145.545658           83.880000
# 4658   Norway  2004    60893.410993           77.690000
# 6881  Andorra  2004             NaN           26.837954

# %%
my_list = ['Iceland','Bermuda','Norway','Denmark','Andorra']
top_5_2009=year09_df.query('Country in @my_list')
top_5_2009
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 566   Bermuda  2009    89961.982744               83.25
# 1457  Denmark  2009    50274.075696               86.84
# 2630  Iceland  2009    48177.084123               93.00
# 4653   Norway  2009    61886.564498               92.08
# 6876  Andorra  2009             NaN               78.53

# %% [markdown]
# 26.	Create a DataFrame called top_5_internet **from the combined DataFrame that has all three years _for the 5 countries that had the greatest 2014 internet usage_**. You should have 15 rows. Check that this is true.

# %%
my_list = ['Iceland','Bermuda','Norway','Denmark','Andorra']
top_5_2014=year14_df.query('Country in @my_list')
top_5_2014
# Out:
#       Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 561   Bermuda  2014    77361.104881               96.80
# 1452  Denmark  2014    52214.537753               95.99
# 2625  Iceland  2014    49652.149500               98.16
# 4648   Norway  2014    62589.373548               96.30
# 6871  Andorra  2014             NaN               95.90

# %%
concat_data=pd.concat([top_5_2004,top_5_2009,top_5_2014])

# %%
concat_data
# Out:
#               Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 6019           Sweden  2004    44496.023401               83.89
# 2635          Iceland  2004    45145.545658               83.88
# 1462          Denmark  2004    50607.628971               80.93
# 4658           Norway  2004    60893.410993               77.69
# 7400  Korea (Rep. of)  2004             NaN               72.70
# 2630          Iceland  2009    48177.084123               93.00
# 4653           Norway  2009    61886.564498               92.08
# 6014           Sweden  2009    45638.035577               91.00
# 4443      Netherlands  2009    51772.424928               89.63
# 3696       Luxembourg  2009   104932.811953               87.31
# 2625          Iceland  2014    49652.149500               98.16
# 561           Bermuda  2014    77361.104881               96.80
# 4648           Norway  2014    62589.373548               96.30
# 1452          Denmark  2014    52214.537753               95.99
# ...

# %% [markdown]
# 27.	Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014?

# %% [markdown]
# Create a seaborn FacetGrid to show the internet usage trend across the years 2004, 2009, and 2014 for these 5 countries (those with the highest reported internet use in 2014). Which country had the greatest growth between 2004 and 2014?

# %%
g=sns.FacetGrid(data=concat_data, col="Country")
g.map_dataframe(sns.scatterplot,x="Year", y="Internet_Users_Pct")

# %% [markdown]
# 28.	Repeat the steps above to look at the trend for the 5 countries with the lowest 2014 internet usage. Which country has consistently had the least internet use?

# %%
year14_df.sort_values(by = 'Internet_Users_Pct', ascending= True).head(5)
# Out:
#                           Country  Year  GDP_Per_Capita  Internet_Users_Pct
# 7079  Dem. People's Rep. of Korea  2014             NaN                0.00
# 7137                      Eritrea  2014             NaN                0.99
# 6219                  Timor-Leste  2014     3264.568070                1.14
# 827                       Burundi  2014      886.235777                1.38
# 7674                      Somalia  2014             NaN                1.63

# %%
my_list = ['Dem. Peoples Rep. of Korea','Eritrea','Timor-Leste','Brundi']
top_5_2014=year14_df.query('Country in @my_list')
top_5_2014
